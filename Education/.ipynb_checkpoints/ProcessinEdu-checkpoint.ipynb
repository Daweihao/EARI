# %%
import pandas as pd

# %%
file1 = "S1501_education_censusTract_selected.xlsx"
xl = pd.ExcelFile(file)
xl.sheet_names
edu_pd = xl.parse('MA')
edu_pd
# Out:
#                     GEO.id      GEO.id2  \
# 0                       Id          Id2
# 1     1400000US25025000100  25025000100
# 2     1400000US25025100100  25025100100
# 3     1400000US25025100200  25025100200
# 4     1400000US25025100300  25025100300
# 5     1400000US25025100400  25025100400
# 6     1400000US25025100500  25025100500
# 7     1400000US25025100601  25025100601
# 8     1400000US25025100603  25025100603
# 9     1400000US25025100700  25025100700
# 10    1400000US25025100800  25025100800
# 11    1400000US25025100900  25025100900
# 12    1400000US25001010100  25001010100
# 13    1400000US25025010103  25025010103
# 14    1400000US25025010104  25025010104
# 15    1400000US25025101001  25025101001
# 16    1400000US25025101002  25025101002
# 17    1400000US25025101101  25025101101
# 18    1400000US25025101102  25025101102
# 19    1400000US25025010203  25025010203
# 20    1400000US25025010204  25025010204
# 21    1400000US25001010206  25001010206
# ...

# %%
file2 = "S1501_education_state.xlsx"
xl2 = pd.ExcelFile(file2)
state_edu = xl2.parse('Education_State')
state_edu
# Out:
#         GEO.id GEO.id2 GEO.display-label  \
# 0           Id     Id2         Geography
# 1  0400000US25      25     Massachusetts
#
#                                 HC01_EST_VC02  \
# 0  Total; Estimate; Population 18 to 24 years
# 1                                      701594
#
#                                        HC01_MOE_VC02  \
# 0  Total; Margin of Error; Population 18 to 24 years
# 1                                                544
#
#                                   HC02_EST_VC02  \
# 0  Percent; Estimate; Population 18 to 24 years
# 1                                           (X)
#
#                                        HC02_MOE_VC02  \
# 0  Percent; Margin of Error; Population 18 to 24 ...
# 1                                                (X)
#
#                                 HC03_EST_VC02  \
# 0  Males; Estimate; Population 18 to 24 years
# 1                                      350279
#
#                                        HC03_MOE_VC02  \
# ...

# %%
counts = edu_pd['HC01_EST_VC06']+ edu_pd['HC01_EST_VC22']+edu_pd['HC01_EST_VC26']+edu_pd['HC01_EST_VC30']+edu_pd['HC01_EST_VC34']
# Out:
# 0       NaN
# 1       1.0
# 2       0.0
# 3       0.0
# 4       0.0
# 5       0.0
# 6       0.0
# 7       1.0
# 8       1.0
# 9       1.0
# 10      1.0
# 11      0.0
# 12      1.0
# 13      1.0
# 14      1.0
# 15      0.0
# 16      0.0
# 17      0.0
# 18      0.0
# 19      1.0
# 20      1.0
# 21      1.0
# 22      1.0
# 23      1.0
# 24      1.0
# 25      1.0
# 26      1.0
# 27      1.0
# 28      1.0
# 29      1.0
#        ...
# 1449    0.0
# 1450    0.0
# 1451    1.0
# 1452    0.0
# 1453    0.0
# 1454    0.0
# 1455    1.0
# 1456    1.0
# 1457    0.0
# 1458    0.0
# 1459    1.0
# 1460    1.0
# 1461    0.0
# 1462    1.0
# 1463    1.0
# 1464    1.0
# 1465    1.0
# 1466    0.0
# 1467    1.0
# 1468    1.0
# 1469    0.0
# 1470    0.0
# 1471    1.0
# 1472    1.0
# 1473    1.0
# 1474    1.0
# 1475    1.0
# 1476    1.0
# 1477    1.0
# 1478    1.0
# Name: 25+4year_degree, Length: 1479, dtype: float64
